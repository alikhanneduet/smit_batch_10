# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cars.csv')

# %%
df.head()

# %%
df['owner'].unique()

# %% [markdown]
# ## 1. OneHotEncoding using Pandas

# %%
pd.get_dummies(df,columns=['fuel','owner'])

# %% [markdown]
# ## 2. K-1 OneHotEncoding

# %% [markdown]
# - multicolinearity: feature ka apas me depend krna

# %% [markdown]
# we drop first column below to avoid multicolinearity

# %%
pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)

# %% [markdown]
# ## 3. OneHotEncoding using Sklearn

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=2)

# %%
X_train.head()

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop='first',sparse_output=True,dtype=np.int32)

# %%
X_train_new = ohe.fit_transform(X_train[['fuel','owner']])
X_train_new = X_train_new.toarray()

# %%
X_test_new = ohe.transform(X_test[['fuel','owner']])
X_test_new = X_test_new.toarray()

# %%
X_test_new

# %%
X_train_new

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_new))

# %% [markdown]
# ## 4. OneHotEncoding with Top Categories

# %%
counts = df['brand'].value_counts()
counts

# %%
df['brand'].nunique()

# %%
threshold = 100

# %%
counts[counts <= threshold].index
# Out:
# Index(['Nissan', 'Jaguar', 'Volvo', 'Datsun', 'Mercedes-Benz', 'Fiat', 'Audi',
#        'Lexus', 'Jeep', 'Mitsubishi', 'Land', 'Force', 'Isuzu', 'Ambassador',
#        'Kia', 'MG', 'Daewoo', 'Ashok', 'Opel', 'Peugeot'],
#       dtype='object', name='brand')

# %%
repl = counts[counts <= threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl, 'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 3595  False      False  False  False    False     False    True    False
# 6329  False      False   True  False    False     False   False    False
# 7707  False      False  False  False    False     False   False    False
# 2106  False      False  False  False    False      True   False    False
# 3317  False      False  False  False    False     False    True    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 3595  False  False   False       False     False
# 6329  False  False   False       False     False
# 7707  False  False    True       False     False
# 2106  False  False   False       False     False
# 3317  False  False   False       False     False
